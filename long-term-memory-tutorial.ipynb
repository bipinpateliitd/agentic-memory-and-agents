# %%
import os
import pprint
from langchain.agents import create_agent
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

load_dotenv(dotenv_path="/home/bipin/Documents/genai/bot/learning/.env")
llm = ChatOpenAI(model="gpt-5-nano")

# %%
filepath="/home/bipin/Documents/genai/bot/learning/notebook/long_term_meme.txt"
with open(filepath, "r") as content:
        current_takeaways = content.read()

# %%
current_takeaways
# Out:
# '"name - yogesh,\nmarried- yes"\nlanguage-preference- hindi\nfood like- panner, coffee\nanswer-length- very short in 1 line"\n\n'

# %%
query="what is newton third law"

# %%
full_context= query+current_takeaways

# %%
output = llm.invoke(full_context)

# %%
print(output.content)
# Out:
# न्यूटन का तीसरा नियम कहता है: हर क्रिया के बराबर और विपरीत प्रतिक्रिया होती है.
