# %%
import pandas  as pd

# %%
s = pd.Series([10, 20, 30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
data = {
    "Name": ["Ravi", "Amit", "Neha"],
    "Age": [25, 30, 28],
    "Salary": [40000, 50000, 45000]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age  Salary
# 0  Ravi   25   40000
# 1  Amit   30   50000
# 2  Neha   28   45000

# %%
df.to_csv('data.csv', index=False)
df.to_excel("data.xlsx", index=False)

df.to_json("data.json", orient="records", indent=2)

# %%
df.head()
df.tail()
df.shape
df.columns
df.info()
df.describe()

# %%
df = pd.read_csv('/home/bipin/Documents/genai/bot/learning/notebook/data/flipkard.csv')

# %%
df.tail(5)
# Out:
#        product_id        product_name        category     brand        seller  \
# 79995  FKP0079996  Prestige Ultra 500          Sports  Prestige     MegaStore
# 79996  FKP0079997      Sony Prime 225         Mobiles      Sony     QuickShop
# 79997  FKP0079998       LG Series 545          Beauty        LG  UrbanRetails
# 79998  FKP0079999    Reebok Model 744            Toys    Reebok     MegaStore
# 79999  FKP0080000      Puma Ultra 650  Home & Kitchen      Puma     ValueKart
#
#       seller_city     price  discount_percent  final_price  rating  ...  \
# 79995     Kolkata  42928.63                 5     40782.20     1.1  ...
# 79996   Ahmedabad  20158.55                10     18142.70     3.8  ...
# 79997     Kolkata  25317.70                20     20254.16     4.7  ...
# 79998     Kolkata   7414.51                40      4448.71     4.3  ...
# 79999     Kolkata  55472.95                30     38831.06     3.8  ...
#
# ...

# %%
df.shape
# Out:
# (80000, 25)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'brand', 'seller',
#        'seller_city', 'price', 'discount_percent', 'final_price', 'rating',
#        'review_count', 'stock_available', 'units_sold', 'listing_date',
#        'delivery_days', 'weight_g', 'warranty_months', 'color', 'size',
#        'return_policy_days', 'is_returnable', 'payment_modes',
#        'shipping_weight_g', 'product_score', 'seller_rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          80000 non-null  object
#  1   product_name        80000 non-null  object
#  2   category            80000 non-null  object
#  3   brand               80000 non-null  object
#  4   seller              80000 non-null  object
#  5   seller_city         80000 non-null  object
#  6   price               80000 non-null  float64
#  7   discount_percent    80000 non-null  int64
#  8   final_price         80000 non-null  float64
#  9   rating              80000 non-null  float64
#  10  review_count        80000 non-null  int64
#  11  stock_available     80000 non-null  int64
#  12  units_sold          80000 non-null  int64
#  13  listing_date        80000 non-null  object
#  14  delivery_days       80000 non-null  int64
# ...

# %%
df.describe()
# Out:
#               price  discount_percent   final_price        rating  \
# count  80000.000000      80000.000000  80000.000000  80000.000000
# mean   30137.256454         21.350625  23697.780600      2.999671
# std    17274.048682         16.354446  14726.821259      1.156238
# min      200.140000          0.000000    101.080000      1.000000
# 25%    15180.205000         10.000000  11341.722500      2.000000
# 50%    30164.455000         20.000000  22571.265000      3.000000
# 75%    45077.087500         40.000000  34521.057500      4.000000
# max    59995.800000         50.000000  59995.800000      5.000000
#
#        review_count  stock_available    units_sold  delivery_days  \
# count  80000.000000     80000.000000  80000.000000   80000.000000
# mean   25102.249875       499.194262   2507.515775       6.006325
# std    14428.769942       288.917706   1439.519972       3.160630
# min        0.000000         0.000000      0.000000       1.000000
# ...

# %%
df['brand'].unique()
# Out:
# array(['Adidas', 'LG', 'Redmi', 'Sony', 'Boat', 'Puma', 'Nike', 'Philips',
#        'Whirlpool', 'Samsung', 'Prestige', 'Dell', 'Reebok', 'Apple',
#        'HP'], dtype=object)

# %%
df[['brand','final_price']]
# Out:
#           brand  final_price
# 0        Adidas     30215.24
# 1            LG     27624.41
# 2         Redmi     30728.70
# 3          Sony     23217.94
# 4          Boat     14181.34
# ...         ...          ...
# 79995  Prestige     40782.20
# 79996      Sony     18142.70
# 79997        LG     20254.16
# 79998    Reebok      4448.71
# 79999      Puma     38831.06
#
# [80000 rows x 2 columns]

# %%
df.iloc[8:12]
# Out:
#     product_id         product_name        category      brand      seller  \
# 8   FKP0000009  Whirlpool Model 764            Toys  Whirlpool   MegaStore
# 9   FKP0000010    Philips Prime 114     Electronics    Philips     BestBuy
# 10  FKP0000011    Samsung Ultra 702  Home & Kitchen    Samsung   SuperMart
# 11  FKP0000012   Philips Series 768            Toys    Philips  SmartDeals
#
#    seller_city     price  discount_percent  final_price  rating  ...  \
# 8      Chennai  26866.61                30     18806.63     2.0  ...
# 9    Bengaluru  53392.85                15     45383.92     4.5  ...
# 10       Delhi  35385.77                50     17692.88     2.6  ...
# 11      Mumbai   1364.39                10      1227.95     1.0  ...
#
#     weight_g  warranty_months   color      size  return_policy_days  \
# 8     857.60               24  Silver       NaN                   7
# 9     288.08               36   Green         S                  10
# ...

# %%
df.isnull()
df.isnull().sum()
df.dropna()
df.fillna(0)

# %%
df.isnull().sum()
# Out:
# product_id                0
# product_name              0
# category                  0
# brand                     0
# seller                    0
# seller_city               0
# price                     0
# discount_percent          0
# final_price               0
# rating                    0
# review_count              0
# stock_available           0
# units_sold                0
# listing_date              0
# delivery_days             0
# weight_g                  0
# warranty_months           0
# color                     0
# size                  13484
# return_policy_days        0
# is_returnable             0
# payment_modes             0
# shipping_weight_g         0
# product_score             0
# seller_rating             0
# dtype: int64

# %%
df2=df.dropna()

# %%
df3=df.fillna(0)

# %%
df3.isnull().sum()
# Out:
# product_id            0
# product_name          0
# category              0
# brand                 0
# seller                0
# seller_city           0
# price                 0
# discount_percent      0
# final_price           0
# rating                0
# review_count          0
# stock_available       0
# units_sold            0
# listing_date          0
# delivery_days         0
# weight_g              0
# warranty_months       0
# color                 0
# size                  0
# return_policy_days    0
# is_returnable         0
# payment_modes         0
# shipping_weight_g     0
# product_score         0
# seller_rating         0
# dtype: int64

# %%
df2.shape
# Out:
# (66516, 25)

# %%
df.groupby('brand').size()
# Out:
# brand
# Adidas       5281
# Apple        5389
# Boat         5258
# Dell         5341
# HP           5297
# LG           5345
# Nike         5358
# Philips      5340
# Prestige     5401
# Puma         5409
# Redmi        5340
# Reebok       5387
# Samsung      5345
# Sony         5287
# Whirlpool    5222
# dtype: int64

# %%
brand_category_rating = df.groupby(['category', 'brand'])['rating'].mean().round(2)
brand_category_rating
# Out:
# category    brand
# Appliances  Adidas       2.97
#             Apple        3.01
#             Boat         3.07
#             Dell         3.02
#             HP           3.06
#                          ...
# Toys        Redmi        2.97
#             Reebok       2.98
#             Samsung      3.02
#             Sony         3.04
#             Whirlpool    2.97
# Name: rating, Length: 120, dtype: float64

# %%
df.iloc[0]        # index-based
df.loc[0]         # label-based

# %%
df = pd.DataFrame({
    "Name": ["Ravi", "Amit", "Neha", None],
    "Age": [25, None, 28, 30],
    "Salary": [40000, 50000, None, None]
})

df
# Out:
#    Name   Age   Salary
# 0  Ravi  25.0  40000.0
# 1  Amit   NaN  50000.0
# 2  Neha  28.0      NaN
# 3  None  30.0      NaN

# %%
df.isnull()
df.isnull().sum()
df.dropna()
df.fillna(0)

# %%
flipkart = pd.read_csv('data/flipkard.csv')
heart = pd.read_csv('data/Heart_disease.csv')
